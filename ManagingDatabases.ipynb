# %%
import os 
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx',
#  'supermarkets_commas.txt',
#  'Untitled.ipynb']

# %%
import pandas

# %%
df = pandas.read_csv("supermarkets.csv")
df.set_index("ID")
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12
# 6          20

# %%
df2 = pandas.read_json("supermarkets.json")
df2.set_index("ID")
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %%
df3 = pandas.read_excel("supermarkets.xlsx",sheet_name=0)
df3.set_index("ID")
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
# 6   551 Alvarado St  San Francisco          CA 94114     USA       Richvalley
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12
# 6                    20

# %%
df4 = pandas.read_csv("supermarkets_commas.txt")
df4
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
df5 = pandas.read_csv("supermarkets-semi-colons.txt",sep=";")
df5 = df5.set_index("Address")
df5
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df5.loc["735 Dolores St":"3995 23rd St","Country":"Employees"]
# Out:
#                Country          Name  Employees
# Address
# 735 Dolores St     USA   Bready Shop         15
# 332 Hill St        USA   Super River         25
# 3995 23rd St       USA    Ben's Shop         10

# %%
df5
# Out:
#                  ID           City             State Country          Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA       Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA   Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA   Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA    Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA       Sanchez
# 551 Alvarado St   6  San Francisco          CA 94114     USA    Richvalley
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12
# 551 Alvarado St         20

# %%
df5.iloc[1:4,3:]
# Out:
#                Country          Name  Employees
# Address
# 735 Dolores St     USA   Bready Shop         15
# 332 Hill St        USA   Super River         25
# 3995 23rd St       USA    Ben's Shop         10

# %%
df5
# Out:
#                  ID           City       State Country         Name  Employees
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira          8
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop         15
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop         10
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez         12
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley         20

# %%
df5.shape[0]
# Out:
# 5

# %%
df5["Continent"] = df5["Country"]+","+"North America"
df5
# Out:
#                  ID           City       State Country         Name  \
# Address
# 3666 21st St      1  San Francisco    CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco    CA 94119     USA  Bready Shop
# 3995 23rd St      4  San Francisco    CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco  California     USA      Sanchez
# 551 Alvarado St   6  San Francisco    CA 94114     USA   Richvalley
#
#                  Employees          Continent
# Address
# 3666 21st St             8  USA,North America
# 735 Dolores St          15  USA,North America
# 3995 23rd St            10  USA,North America
# 1056 Sanchez St         12  USA,North America
# 551 Alvarado St         20  USA,North America

# %%
df5_t = df5.T
df5_t
# Out:
# Address         3666 21st St     735 Dolores St       3995 23rd St  \
# ID                         1                  2                  4
# City           San Francisco      San Francisco      San Francisco
# State               CA 94114           CA 94119           CA 94114
# Country                  USA                USA                USA
# Name                 Madeira        Bready Shop         Ben's Shop
# Employees                  8                 15                 10
# Continent  USA,North America  USA,North America  USA,North America
#
# Address      1056 Sanchez St    551 Alvarado St
# ID                         5                  6
# City           San Francisco      San Francisco
# State             California           CA 94114
# Country                  USA                USA
# Name                 Sanchez         Richvalley
# Employees                 12                 20
# Continent  USA,North America  USA,North America

# %%
df5_t["My address"] = [7,"My city","My state","My country","My name",10,"My continent"]
df5 = df5_t.T
df5
# Out:
#                 ID           City       State     Country         Name  \
# Address
# 3666 21st St     1  San Francisco    CA 94114         USA      Madeira
# 735 Dolores St   2  San Francisco    CA 94119         USA  Bready Shop
# 3995 23rd St     4  San Francisco    CA 94114         USA   Ben's Shop
# 1056 Sanchez St  5  San Francisco  California         USA      Sanchez
# 551 Alvarado St  6  San Francisco    CA 94114         USA   Richvalley
# My address       7        My city    My state  My country      My name
#
#                 Employees          Continent
# Address
# 3666 21st St            8  USA,North America
# 735 Dolores St         15  USA,North America
# 3995 23rd St           10  USA,North America
# 1056 Sanchez St        12  USA,North America
# 551 Alvarado St        20  USA,North America
# My address             10       My continent

# %%
df5.drop["My address"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-4acd192a798c> in <module>()
# ----> 1 df5.drop["My address"]
#
# TypeError: 'method' object is not subscriptable

# %%
df5 = df5.iloc[0:5,:]

# %%
df5
# Out:
#                 ID           City       State Country         Name Employees  \
# Address
# 3666 21st St     1  San Francisco    CA 94114     USA      Madeira         8
# 735 Dolores St   2  San Francisco    CA 94119     USA  Bready Shop        15
# 3995 23rd St     4  San Francisco    CA 94114     USA   Ben's Shop        10
# 1056 Sanchez St  5  San Francisco  California     USA      Sanchez        12
# 551 Alvarado St  6  San Francisco    CA 94114     USA   Richvalley        20
#
#                          Continent
# Address
# 3666 21st St     USA,North America
# 735 Dolores St   USA,North America
# 3995 23rd St     USA,North America
# 1056 Sanchez St  USA,North America
# 551 Alvarado St  USA,North America

# %%
from geopy.geocoders import Nominatim

# %%
nom = Nominatim(scheme="http")

# %%
nom.geocode("3995 23rd St, San Francisco, CA 94114")
# Out:
# Location(3995, 23rd Street, Noe Valley, SF, California, 94114, United States of America, (37.7529648, -122.4317141, 0.0))

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Address"]=df["Address"] + ", " + df["City"] + ", " + df["State"] + ", " + df["Country"]
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20

# %%
df["Coordinates"] = df["Address"].apply(nom.geocode)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-72835af78b8f> in <module>()
#       1 df["Coordinates"] = df["Address"].apply(nom.geocode)
# ----> 2 df.Coordinates.apply(latitude)
#
# NameError: name 'latitude' is not defined

# %%
df["Latitude"] = df.Coordinates.apply(lambda x: x.latitude if x != None else None)
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                           Coordinate  \
# ...

# %%
df = df.drop("Coordinate",1)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude
# ...

# %%
df["Longitude"] = df.Coordinates.apply(lambda x: x.longitude if x != None else None)

# %%
df
# Out:
#    ID                                            Address           City  \
# 0   1         3666 21st St, San Francisco, CA 94114, USA  San Francisco
# 1   2       735 Dolores St, San Francisco, CA 94119, USA  San Francisco
# 2   3  332 Hill St, San Francisco, California 94114, USA  San Francisco
# 3   4         3995 23rd St, San Francisco, CA 94114, USA  San Francisco
# 4   5    1056 Sanchez St, San Francisco, California, USA  San Francisco
# 5   6      551 Alvarado St, San Francisco, CA 94114, USA  San Francisco
#
#               State Country         Name  Employees  \
# 0          CA 94114     USA      Madeira          8
# 1          CA 94119     USA  Bready Shop         15
# 2  California 94114     USA  Super River         25
# 3          CA 94114     USA   Ben's Shop         10
# 4        California     USA      Sanchez         12
# 5          CA 94114     USA   Richvalley         20
#
#                                          Coordinates   Latitude   Longitude
# ...
